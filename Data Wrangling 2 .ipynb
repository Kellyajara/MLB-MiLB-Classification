# %%
import pandas as pd

# %% [markdown]
# # 2023

# %%
team_23 = pd.read_csv('/Users/kellyjara/Desktop/Datasets/Baseball/2023 Team - exit_velocity.csv')
team_23
# Out:
#          team team_id  attempts  avg_hit_angle  anglesweetspotpercent  \
# 0   Athletics     OAK      1881           16.2                   35.1
# 1     Rockies     COL      1860           11.6                   34.8
# 2   Cardinals     STL      1806           10.5                   35.4
# 3   Guardians     CLE      1781           13.3                   33.7
# 4     Red Sox     BOS      1771           12.4                   34.6
# 5        Reds     CIN      1770           14.2                   34.4
# 6   Nationals     WSH      1757           12.1                   35.7
# 7      Angels     LAA      1750           13.7                   34.9
# 8     D-backs      AZ      1743           12.4                   35.8
# 9        Rays      TB      1730           10.5                   32.8
# 10    Brewers     MIL      1728           13.1                   33.5
# 11     Royals      KC      1712           13.9                   33.9
# ...

# %%
pitchers_23 = pd.read_csv('/Users/kellyjara/Desktop/Datasets/Baseball/exit_velocity 2023 (2).csv')
pitchers_23
# Out:
#     last_name  first_name  player_id  attempts  avg_hit_angle  \
# 0      Corbin     Patrick     571578       276           10.0
# 1      Bieber       Shane     669456       275           10.7
# 2     Mikolas       Miles     571945       267           12.7
# 3      Gibson        Kyle     502043       259           11.4
# 4       Lyles      Jordan     543475       253           20.7
# ..        ...         ...        ...       ...            ...
# 383  Hamilton         Ian     641656        49            1.6
# 384  Williams       Devin     642207        46            7.5
# 385  Bautista       Félix     642585        45           13.9
# 386   Chapman     Aroldis     547973        42           13.8
# 387      Díaz      Alexis     664747        42           22.2
#
#      anglesweetspotpercent  max_hit_speed  avg_hit_speed  fbld    gb  \
# 0                     37.7          113.2           91.7  95.6  88.7
# 1                     33.8          116.3           91.5  94.0  89.8
# ...

# %% [markdown]
# # 2022

# %%
team_22 = pd.read_csv('/Users/kellyjara/Desktop/Datasets/Baseball/2022 Team - exit_velocity (1).csv')
team_22
# Out:
#          team team_id  attempts  avg_hit_angle  anglesweetspotpercent  \
# 0     Rockies     COL      4453           11.4                   34.5
# 1      Royals      KC      4398           11.5                   33.9
# 2   Nationals     WSH      4366           14.1                   34.2
# 3   Athletics     OAK      4341           13.7                   33.1
# 4     Pirates     PIT      4336           12.0                   33.8
# 5     Orioles     BAL      4331           12.1                   33.8
# 6   Cardinals     STL      4285            9.7                   33.0
# 7      Tigers     DET      4283           13.5                   33.6
# 8     D-backs      AZ      4282           14.4                   34.5
# 9     Red Sox     BOS      4223           12.2                   34.6
# 10     Giants      SF      4202            9.4                   31.5
# 11    Rangers     TEX      4198           10.8                   32.8
# ...

# %% [markdown]
# # 2021

# %%
team_21 = pd.read_csv('/Users/kellyjara/Desktop/Datasets/Baseball/2021 Team - exit_velocity (2).csv')
team_21
# Out:
#          team team_id  attempts  avg_hit_angle  anglesweetspotpercent  \
# 0     D-backs      AZ      4399           14.2                   34.5
# 1     Orioles     BAL      4387           14.7                   35.3
# 2     Rangers     TEX      4287           13.0                   34.0
# 3      Tigers     DET      4250           12.3                   31.9
# 4   Athletics     OAK      4222           14.6                   34.2
# 5    Mariners     SEA      4221           14.2                   33.9
# 6       Twins     MIN      4214           13.6                   33.7
# 7     Rockies     COL      4172           11.2                   33.1
# 8        Cubs     CHC      4146           10.9                   34.0
# 9     Pirates     PIT      4144           13.6                   34.7
# 10     Royals      KC      4129           12.6                   35.4
# 11  Cardinals     STL      4128           11.9                   33.4
# ...
